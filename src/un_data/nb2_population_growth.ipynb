# %% [markdown]
# # Population growth - UN data
# In this notebook, there will be an analysis of the population growth dataset from the United Nations.

# %%
# package imports
from config import input_folder_structure, population_growth_filename
from read_data import get_raw_dataset

# %%
# initialise data frame
df = get_raw_dataset(
    input_folder_structure=input_folder_structure,
    input_filename=population_growth_filename,
    type_of_data="gdp",
)
df.head(5)

# %% [markdown]
# ## Explore the data
# First, it is good to know

# %%
df.columns

# %%
df.info()
